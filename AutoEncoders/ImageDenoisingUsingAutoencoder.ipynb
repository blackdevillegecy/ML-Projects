# %%
import keras
from keras import layers

from keras.datasets import fashion_mnist
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train,_), (x_test,_) = fashion_mnist.load_data()

# %%
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

x_train = x_train.reshape(len(x_train), 28, 28, 1)
x_test = x_test.reshape(len(x_test), 28, 28, 1)

# %%
n=10
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(x_train[i])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# %%
# adding noise 
n_factor = 0.3

n_x_train = x_train + n_factor*np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
n_x_test = x_test + n_factor*np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

n_x_train = np.clip(n_x_train, 0.0, 1.0)
n_x_test = np.clip(n_x_test, 0.0, 1.0)

# %%
n=10
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(n_x_train[i])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# %%
n_x_train = n_x_train.reshape(len(n_x_train), 784)
n_x_test = n_x_test.reshape(len(n_x_test), 784)

x_train = x_train.reshape(len(x_train), 784)
x_test = x_test.reshape(len(x_test), 784)

# %%
input = keras.Input(shape=(784,))
encoded = layers.Dense(512, activation='relu')(input)
encoded = layers.Dense(256, activation='relu')(encoded)
encoded = layers.Dense(128, activation='relu')(encoded)
encoded = layers.Dense(64, activation='relu')(encoded)

decoded = layers.Dense(64, activation='relu')(encoded)
decoded = layers.Dense(128, activation='relu')(decoded)
decoded = layers.Dense(256, activation='relu')(decoded)
decoded = layers.Dense(512, activation='relu')(decoded)
decoded = layers.Dense(784, activation='sigmoid')(decoded)

autoencoder = keras.Model(input, decoded)

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(n_x_train, x_train, batch_size=256, epochs=50, validation_data=(n_x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 11s 38ms/step - loss: 0.3771 - val_loss: 0.3230
# Epoch 2/50
# 235/235 [==============================] - 9s 38ms/step - loss: 0.3134 - val_loss: 0.3102
# Epoch 3/50
# 235/235 [==============================] - 18s 79ms/step - loss: 0.3054 - val_loss: 0.3054
# Epoch 4/50
# 235/235 [==============================] - 23s 100ms/step - loss: 0.3004 - val_loss: 0.3014
# Epoch 5/50
# 235/235 [==============================] - 22s 94ms/step - loss: 0.2971 - val_loss: 0.2979
# Epoch 6/50
# 235/235 [==============================] - 21s 91ms/step - loss: 0.2946 - val_loss: 0.2965
# Epoch 7/50
# 235/235 [==============================] - 21s 89ms/step - loss: 0.2926 - val_loss: 0.2956
# Epoch 8/50
# 235/235 [==============================] - 21s 91ms/step - loss: 0.2909 - val_loss: 0.2936
# Epoch 9/50
# 235/235 [==============================] - 21s 88ms/step - loss: 0.2895 - val_loss: 0.2921
# Epoch 10/50
# 235/235 [==============================] - 22s 95ms/step - loss: 0.2883 - val_loss: 0.2918
# Epoch 11/50
# 235/235 [==============================] - 24s 104ms/step - loss: 0.2870 - val_loss: 0.2913
# Epoch 12/50
# 235/235 [==============================] - 21s 90ms/step - loss: 0.2862 - val_loss: 0.2899
# Epoch 13/50
# 235/235 [==============================] - 22s 93ms/step - loss: 0.2851 - val_loss: 0.2886
# Epoch 14/50
# 235/235 [==============================] - 23s 99ms/step - loss: 0.2842 - val_loss: 0.2883
# Epoch 15/50
# 235/235 [==============================] - 23s 98ms/step - loss: 0.2839 - val_loss: 0.2875
# Epoch 16/50
# 235/235 [==============================] - 25s 106ms/step - loss: 0.2830 - val_loss: 0.2869
# Epoch 17/50
# 235/235 [==============================] - 23s 98ms/step - loss: 0.2824 - val_loss: 0.2870
# Epoch 18/50
# 235/235 [==============================] - 23s 96ms/step - loss: 0.2818 - val_loss: 0.2862
# Epoch 19/50
# 235/235 [==============================] - 22s 94ms/step - loss: 0.2813 - val_loss: 0.2861
# Epoch 20/50
# 235/235 [==============================] - 22s 95ms/step - loss: 0.2809 - val_loss: 0.2864
# Epoch 21/50
# 235/235 [==============================] - 24s 100ms/step - loss: 0.2804 - val_loss: 0.2854
# Epoch 22/50
# 235/235 [==============================] - 23s 98ms/step - loss: 0.2802 - val_loss: 0.2854
# Epoch 23/50
# 235/235 [==============================] - 22s 94ms/step - loss: 0.2797 - val_loss: 0.2859
# Epoch 24/50
# 235/235 [==============================] - 23s 100ms/step - loss: 0.2794 - val_loss: 0.2854
# Epoch 25/50
# 235/235 [==============================] - 22s 92ms/step - loss: 0.2790 - val_loss: 0.2852
# Epoch 26/50
# 235/235 [==============================] - 21s 90ms/step - loss: 0.2786 - val_loss: 0.2851
# Epoch 27/50
# 235/235 [==============================] - 22s 96ms/step - loss: 0.2783 - val_loss: 0.2844
# Epoch 28/50
# 235/235 [==============================] - 24s 100ms/step - loss: 0.2781 - val_loss: 0.2840
# Epoch 29/50
# 235/235 [==============================] - 24s 103ms/step - loss: 0.2777 - val_loss: 0.2841
# Epoch 30/50
# 235/235 [==============================] - 22s 95ms/step - loss: 0.2775 - val_loss: 0.2843
# Epoch 31/50
# 235/235 [==============================] - 22s 95ms/step - loss: 0.2772 - val_loss: 0.2843
# Epoch 32/50
# 235/235 [==============================] - 25s 104ms/step - loss: 0.2770 - val_loss: 0.2835
# Epoch 33/50
# 235/235 [==============================] - 20s 86ms/step - loss: 0.2767 - val_loss: 0.2836
# Epoch 34/50
# 235/235 [==============================] - 23s 97ms/step - loss: 0.2765 - val_loss: 0.2847
# Epoch 35/50
# 235/235 [==============================] - 24s 103ms/step - loss: 0.2764 - val_loss: 0.2833
# Epoch 36/50
# 235/235 [==============================] - 24s 101ms/step - loss: 0.2761 - val_loss: 0.2837
# Epoch 37/50
# 235/235 [==============================] - 24s 104ms/step - loss: 0.2759 - val_loss: 0.2832
# Epoch 38/50
# 235/235 [==============================] - 23s 99ms/step - loss: 0.2757 - val_loss: 0.2832
# Epoch 39/50
# 235/235 [==============================] - 22s 96ms/step - loss: 0.2755 - val_loss: 0.2831
# Epoch 40/50
# 235/235 [==============================] - 21s 91ms/step - loss: 0.2753 - val_loss: 0.2833
# Epoch 41/50
# 235/235 [==============================] - 22s 95ms/step - loss: 0.2752 - val_loss: 0.2828
# Epoch 42/50
# 235/235 [==============================] - 23s 98ms/step - loss: 0.2750 - val_loss: 0.2828
# Epoch 43/50
# 235/235 [==============================] - 25s 107ms/step - loss: 0.2747 - val_loss: 0.2831
# Epoch 44/50
# 235/235 [==============================] - 14s 60ms/step - loss: 0.2748 - val_loss: 0.2827
# Epoch 45/50
# 235/235 [==============================] - 10s 41ms/step - loss: 0.2746 - val_loss: 0.2828
# Epoch 46/50
# 235/235 [==============================] - 9s 40ms/step - loss: 0.2745 - val_loss: 0.2828
# Epoch 47/50
# 235/235 [==============================] - 11s 48ms/step - loss: 0.2742 - val_loss: 0.2828
# Epoch 48/50
# 235/235 [==============================] - 19s 79ms/step - loss: 0.2742 - val_loss: 0.2829
# Epoch 49/50
# 235/235 [==============================] - 18s 76ms/step - loss: 0.2740 - val_loss: 0.2829
# Epoch 50/50
# 235/235 [==============================] - 19s 80ms/step - loss: 0.2741 - val_loss: 0.2827

# %%
decoded_images = autoencoder.predict(n_x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
n=10
plt.figure(figsize=(20, 6))
for i in range(n):
    ax = plt.subplot(3, n, i+1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    
    ax = plt.subplot(3, n, i+1+n)
    plt.imshow(n_x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    
    ax = plt.subplot(3, n, i+1+n+n)
    plt.imshow(decoded_images[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()
