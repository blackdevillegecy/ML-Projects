# %%
import keras
from keras import layers

from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

# %%
encoded_dim=36

# %%
input = keras.Input(shape=(784,))
encoded = layers.Dense(encoded_dim, activation='relu')(input)
decoded = layers.Dense(784, activation='sigmoid')(encoded)

# %%
autoencoder=keras.Model(input, decoded)

# %%
autoencoder.compile(optimizer="adam", loss="binary_crossentropy")

# %%
(x_train,_), (x_test,_) = mnist.load_data()

# %%
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255
x_train = x_train.reshape(len(x_train), np.prod(x_train.shape[1:]))
x_test = x_test.reshape(len(x_test), np.prod(x_test.shape[1:]))

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train, epochs=70, batch_size=256, validation_data=(x_test, x_test))
# Out:
# Epoch 1/70
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2725 - val_loss: 0.1876
# Epoch 2/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1679 - val_loss: 0.1501
# Epoch 3/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1410 - val_loss: 0.1300
# Epoch 4/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1248 - val_loss: 0.1172
# Epoch 5/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1141 - val_loss: 0.1085
# Epoch 6/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1069 - val_loss: 0.1026
# Epoch 7/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1015 - val_loss: 0.0981
# Epoch 8/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0976 - val_loss: 0.0949
# Epoch 9/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0949 - val_loss: 0.0926
# Epoch 10/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0930 - val_loss: 0.0911
# Epoch 11/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0917 - val_loss: 0.0900
# Epoch 12/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0909 - val_loss: 0.0893
# Epoch 13/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0903 - val_loss: 0.0889
# Epoch 14/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0900 - val_loss: 0.0885
# Epoch 15/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0897 - val_loss: 0.0884
# Epoch 16/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0895 - val_loss: 0.0882
# Epoch 17/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0893 - val_loss: 0.0880
# Epoch 18/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0892 - val_loss: 0.0879
# Epoch 19/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0890 - val_loss: 0.0878
# Epoch 20/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0889 - val_loss: 0.0877
# Epoch 21/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0889 - val_loss: 0.0876
# Epoch 22/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0888 - val_loss: 0.0876
# Epoch 23/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0887 - val_loss: 0.0875
# Epoch 24/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0887 - val_loss: 0.0876
# Epoch 25/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0886 - val_loss: 0.0875
# Epoch 26/70
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0886 - val_loss: 0.0874
# Epoch 27/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0885 - val_loss: 0.0875
# Epoch 28/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0885 - val_loss: 0.0873
# Epoch 29/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0884 - val_loss: 0.0874
# Epoch 30/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0884 - val_loss: 0.0875
# Epoch 31/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0884 - val_loss: 0.0873
# Epoch 32/70
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0884 - val_loss: 0.0874
# Epoch 33/70
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0883 - val_loss: 0.0873
# Epoch 34/70
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0883 - val_loss: 0.0873
# Epoch 35/70
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0883 - val_loss: 0.0872
# Epoch 36/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0883 - val_loss: 0.0873
# Epoch 37/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0883 - val_loss: 0.0872
# Epoch 38/70
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0883 - val_loss: 0.0872
# Epoch 39/70
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0882 - val_loss: 0.0872
# Epoch 40/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0882 - val_loss: 0.0871
# Epoch 41/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0882 - val_loss: 0.0872
# Epoch 42/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0882 - val_loss: 0.0871
# Epoch 43/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0882 - val_loss: 0.0871
# Epoch 44/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0882 - val_loss: 0.0871
# Epoch 45/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0882 - val_loss: 0.0871
# Epoch 46/70
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0882 - val_loss: 0.0871
# Epoch 47/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0881 - val_loss: 0.0871
# Epoch 48/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0881 - val_loss: 0.0871
# Epoch 49/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0881 - val_loss: 0.0871
# Epoch 50/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0881 - val_loss: 0.0871
# Epoch 51/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0881 - val_loss: 0.0871
# Epoch 52/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0881 - val_loss: 0.0870
# Epoch 53/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0881 - val_loss: 0.0871
# Epoch 54/70
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0881 - val_loss: 0.0871
# Epoch 55/70
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0881 - val_loss: 0.0870
# Epoch 56/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0881 - val_loss: 0.0870
# Epoch 57/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0881 - val_loss: 0.0870
# Epoch 58/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0881 - val_loss: 0.0870
# Epoch 59/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0881 - val_loss: 0.0870
# Epoch 60/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0880 - val_loss: 0.0870
# Epoch 61/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0880 - val_loss: 0.0871
# Epoch 62/70
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0880 - val_loss: 0.0871
# Epoch 63/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0880 - val_loss: 0.0871
# Epoch 64/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0880 - val_loss: 0.0870
# Epoch 65/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0880 - val_loss: 0.0870
# Epoch 66/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0880 - val_loss: 0.0870
# Epoch 67/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0880 - val_loss: 0.0870
# Epoch 68/70
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0880 - val_loss: 0.0870
# Epoch 69/70
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0880 - val_loss: 0.0871
# Epoch 70/70
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0880 - val_loss: 0.0870

# %%
encoder = keras.Model(input, encoded)
encoded_input = keras.Input(shape=(encoded_dim,))
decoded_layer = autoencoder.layers[-1]
decoder = keras.Model(encoded_input, decoded_layer(encoded_input))

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 313/313 [==============================] - 0s 665us/step
# 313/313 [==============================] - 0s 604us/step

# %%
n=15
plt.figure(figsize=(36, 5))
for i in range(n):
    ax = plt.subplot(2, n, i+1)
    plt.imshow(x_test[i].reshape(28, 28))
    
    ax = plt.subplot(2, n, i+1+n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
plt.show()
